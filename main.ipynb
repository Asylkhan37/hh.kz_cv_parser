# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('CV.csv')

# create the scripts to sort dataframe by the salary, age, experience and title (in alphabetical order) 
df = df.sort_values(by=['Salary'])
df = df.sort_values(by=['Age'])
df = df.sort_values(by=['Title'])
df = df.sort_values(by=['Experience Year'])
df = df.sort_values(by=['Experience Month']) 

#create the scripts to calculate minimum, maximum and mean average of the salary of all 
# min_salary = df['Salary'].min()
# max_salary = df['Salary'].max()
# mean_salary = df['Salary'].mean()

# print('Minimum salary: ', min_salary)
# print('Maximum salary: ', max_salary)
# print('Mean average salary: ', mean_salary)

#create the scripts to calculate minimum, maximum and mean average of the salary of each sex, specialization and citizenship. Results must be the dataframe
# df = df.groupby(['Sex', 'Specialization', 'Citizenship'])['Salary'].agg(['min', 'max', 'mean'])

# count_stats = df.groupby(['Citizenship', 'Sex'])['cv'].agg(['count'])
df
# Out:
#                                                 Title  \
# 5   DevOps инженер / AWS+terraform+kubernetes / MLOps
# 6                         ML Engineer, Data scientist
# 13  Начальник отдела ИТ, менеджер ИТ-проектов, сис...
# 0                             Python Django Developer
# 4                       Web-разработчик Python/Django
# 12                                 Программист Python
# 8                            Python Backend Developer
# 16                           Python Backend Developer
# 15                                   Python Developer
# 3                           Программист Python Django
# 18                                        Программист
# 9                 Web-программист, программист Python
# 11                                        Оператор ПК
# 14                                   Специалист по IT
# 1                          Программист Python, Django
# 7                                 Backend разработчик
# ...
