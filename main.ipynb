# %%
import pandas as pd
df = pd.read_csv('CV.csv')
df
# Out:
#                                               Title  \
# 0                                Программист Python
# 1                                  Python Developer
# 2                                Python разработчик
# 3                           middle python developer
# 4                                  Python developer
# 5                                Программист Python
# 6                                  Python Developer
# 7                                  Python Developer
# 8                                Разработчик Python
# 9                           Программист-разработчик
# 10                                 Python Developer
# 11                       Python Backend разработчик
# 12                         Python, Java разработчик
# 13                             Junior Data Engineer
# 14                               Программист Python
# 15                                 Python Developer
# 16  Data scientist, machine learning, web developer
# ...
